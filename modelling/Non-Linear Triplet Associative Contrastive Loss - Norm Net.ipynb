# %%
# Load IPython extension to reload modules
# %load_ext autoreload
# Reload all modules (except those excluded by %aimport) every time before executing the Python code typed.
# %autoreload 2

# %%
import sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
from torch.utils.data import DataLoader
# from torch.optim import lr_scheduler
# Out:
# /mnt/ey/conda_envs/py3.6.3_env1/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /mnt/ey/conda_envs/py3.6.3_env1/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
sys.path.append("../src/")
from dataset import DummyDataset
from network import NormEmbeddingNet, NormClampEmbeddingNet, extract_embedding
from loss import OnlineTripletLoss, OnlineNonLinearTripletLoss
from metric import AverageNonZeroTripletsMetric
from trainer import fit
from sampler import BalancedBatchSampler, SemiHardNegativeTripletSelector, MarginallyHardNegativeTripletSelector
from display import plot_image, plot_2d_circle, plot_2d_embedding

# %% [markdown]
# ## Non-Linear Triplet Associative-Contrastive Loss Function
# $Loss = -ln\left(1-\frac{||Z^a-Z^p||_2}{\beta_1}+\epsilon\right) -ln\left(1-\frac{D-||Z^a-Z^n||_2}{\beta_2}+\epsilon\right)$
# - Associative loss is minimised when distance between two data points of the same class (anchor-postive) is minimised.
# - Contrastive loss is minimised when distance between two data points of the different classes (anchor-negative) is maximised.

# %%
beta1 = 2
beta2 = 2.01
max_dist = 2
d = np.array([v for v in np.arange(0, max_dist, 0.01)])
y1 = -np.log(1-(d/beta1)+1e-8)
y2 = -np.log(1 -((max_dist-d)/beta2)+1e-8)

fig, axes = plt.subplots(1, 3, figsize=(12,4))
ax = axes.item(0)
ax.plot(d, y1, label=r"$-ln\left(1-\frac{||Z^a-Z^p||_2}{\beta_1} + \epsilon\right)$", linewidth=2)
ax.set_title(r"$\beta_1 = {}$".format(beta1))
ax.set_xlabel(r"Anchor-Positive Distance: $||Z^a-Z^p||_2$")
ax.set_ylabel(r"Anchor-Positive Loss")
ax.grid()
ax.legend()

ax = axes.item(1)
ax.plot(d, y2, label=r"$-ln\left(1-\frac{D-||Z^a-Z^n||_2}{\beta_2} + \epsilon\right)$", linewidth=2)
ax.set_title(r"$\beta_2 = {}$, $D = {}$".format(beta2, max_dist))
ax.set_xlabel(r"Anchor-Negative Distance: $||Z^a-Z^n||_2$")
ax.set_ylabel(r"Anchor-Negative Loss")
ax.grid()
ax.legend()

ax = axes.item(2)
ax.plot(d, y1, label=r"$-ln\left(1-\frac{||Z^a-Z^p||_2}{\beta_1} + \epsilon\right)$", linewidth=2)
ax.plot(d, y2, label=r"$-ln\left(1-\frac{d-||Z^a-Z^n||_2}{\beta_2} + \epsilon\right)$", linewidth=2)
ax.grid()
ax.legend()
fig.tight_layout()

# %% [markdown]
# ## Load Dummy Dataset

# %%
ds_dummy = DummyDataset()
# Out:
# Loading Dummy Dataset ...
# Class distribution:
# 0    1000
# 1     136
# Name: class, dtype: int64
# Number of signals: 9
# Number of signal steps: 29
# Number of records: 1136

# %% [markdown]
# ### Examples of Class 0

# %%
for i in range(500, 510):
    data = ds_dummy.__getitem__(i)[0]
    target = ds_dummy.__getitem__(i)[1]
    plot_image(data, target)

# %% [markdown]
# ### Examples of Class 1

# %%
for i in range(0, 10):
    data = ds_dummy.__getitem__(i)[0]
    target = ds_dummy.__getitem__(i)[1]
    plot_image(data, target)

# %%
dict_args = dict()
dict_args["batch_size"] = 256
dict_args["no_cuda"] = False
dict_args["optimizer"] = "Adam"
dict_args["lr"] = 1e-2
dict_args["epochs"] = 50
dict_args["margin"] = 0.5
dict_args["log_interval"] = None
dict_args["seed"] = 1

use_cuda = not dict_args["no_cuda"] and torch.cuda.is_available()

torch.manual_seed(dict_args["seed"])

device = torch.device("cuda" if use_cuda else "cpu")

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

print("use_cuda :", use_cuda)
print("device :", device)
# Out:
# use_cuda : False
# device : cpu

# %%
train_loader = DataLoader(ds_dummy, 
                         batch_size=dict_args["batch_size"], 
                         shuffle=False, **kwargs)

for batch_idx, (data, target) in enumerate(train_loader):
    print(data.shape, target.shape)
    break

train_batch_sampler = BalancedBatchSampler(ds_dummy, n_classes=2, n_samples=256)
online_train_loader = DataLoader(ds_dummy, batch_sampler=train_batch_sampler, **kwargs)

for batch_idx, (data, target) in enumerate(online_train_loader):
    print(data.shape, target.shape)
    break
# Out:
# torch.Size([256, 1, 9, 29]) torch.Size([256])
# torch.Size([392, 1, 9, 29]) torch.Size([392])

# %%
# Select negative point when ap_distance + margin > an_distance 
loss_fn = OnlineNonLinearTripletLoss(MarginallyHardNegativeTripletSelector(dict_args["margin"]),
                                     max_dist=2,
                                     beta1=2,
                                     beta2=2.01,
                                     epsilon=1e-8)

# %%
# loss_fn = OnlineTripletLoss(dict_args["margin"], SemihardNegativeTripletSelector(dict_args["margin"]))

# %%
# loss_fn = OnlineNonLinearTripletLoss(SemiHardNegativeTripletSelector(dict_args["margin"]),
#                                      max_dist=2,
#                                      beta1=2,
#                                      beta2=2.01,
#                                      epsilon=1e-8)

# %%
def load_model(path=None):
    model = NormEmbeddingNet([1, 50, 20], 
                               ds_dummy.n_grps, 
                               ds_dummy.n_steps,
                               kernel_size=3, 
                               dropout=0.1,
                               fc_nodes=[50, 50, 2],
                               p=2)
    if path is not None:
        model.load_state_dict(torch.load(path))
    return model

model = load_model(None)
model = model.to(device)

# %%
#loss_fn = TripletLoss(dict_args["margin"])
optimizer = getattr(torch.optim, dict_args["optimizer"])(model.parameters(), lr=dict_args["lr"])
# scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)

# %% [markdown]
# ## Initial Embeddings

# %%
train_embeddings, train_labels = extract_embedding(train_loader, model, use_cuda)
fig, ax = plt.subplots(figsize=(6,6))
plot_2d_circle()
plot_2d_embedding(train_embeddings, 
                  train_labels, 
                  ax=ax, xlim=[-1.5, 1.5], 
                  ylim=[-1.5, 1.5])

# %% [markdown]
# ## Train Model

# %%
dict_train_loss = {}
list_end_epochs = [50, 500, 1000]
start_epoch = 0
for i, end_epoch in enumerate(list_end_epochs):
    tmp_dict_train_loss, _ = fit(online_train_loader, 
                                         None, 
                                         model, 
                                         loss_fn, 
                                         optimizer, None, 
                                         end_epoch, 
                                         use_cuda, 
                                         dict_args["log_interval"], 
                                         metrics=[AverageNonZeroTripletsMetric()],
                                         start_epoch=start_epoch)
    
    torch.save(model.state_dict(), "nonlinear_triplet_norm_net_{}.pt".format(end_epoch))
    
    start_epoch = end_epoch
    
    dict_train_loss.update(tmp_dict_train_loss)
# Out:
# Epoch [1/50]: Avg. Train Loss: 3.16528 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [2/50]: Avg. Train Loss: 2.74334 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [3/50]: Avg. Train Loss: 2.64925 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [4/50]: Avg. Train Loss: 2.50081 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [5/50]: Avg. Train Loss: 2.49917 | Avg. Non-Zero Triplets: 41819.50000
# Epoch [6/50]: Avg. Train Loss: 2.48546 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [7/50]: Avg. Train Loss: 2.44391 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [8/50]: Avg. Train Loss: 2.40341 | Avg. Non-Zero Triplets: 41818.50000
# Epoch [9/50]: Avg. Train Loss: 2.31480 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [10/50]: Avg. Train Loss: 2.29247 | Avg. Non-Zero Triplets: 41808.00000
# Epoch [11/50]: Avg. Train Loss: 2.25998 | Avg. Non-Zero Triplets: 41819.50000
# Epoch [12/50]: Avg. Train Loss: 2.19805 | Avg. Non-Zero Triplets: 41679.00000
# Epoch [13/50]: Avg. Train Loss: 2.14853 | Avg. Non-Zero Triplets: 41673.50000
# Epoch [14/50]: Avg. Train Loss: 2.11162 | Avg. Non-Zero Triplets: 41653.00000
# Epoch [15/50]: Avg. Train Loss: 2.20837 | Avg. Non-Zero Triplets: 41809.00000
# Epoch [16/50]: Avg. Train Loss: 2.23875 | Avg. Non-Zero Triplets: 41720.00000
# Epoch [17/50]: Avg. Train Loss: 2.27383 | Avg. Non-Zero Triplets: 41787.00000
# Epoch [18/50]: Avg. Train Loss: 2.19760 | Avg. Non-Zero Triplets: 41715.50000
# Epoch [19/50]: Avg. Train Loss: 2.12365 | Avg. Non-Zero Triplets: 41553.50000
# Epoch [20/50]: Avg. Train Loss: 2.14363 | Avg. Non-Zero Triplets: 41699.50000
# Epoch [21/50]: Avg. Train Loss: 2.11575 | Avg. Non-Zero Triplets: 41689.00000
# Epoch [22/50]: Avg. Train Loss: 2.14827 | Avg. Non-Zero Triplets: 41770.50000
# Epoch [23/50]: Avg. Train Loss: 2.15747 | Avg. Non-Zero Triplets: 41661.00000
# Epoch [24/50]: Avg. Train Loss: 2.21630 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [25/50]: Avg. Train Loss: 2.27300 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [26/50]: Avg. Train Loss: 2.21659 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [27/50]: Avg. Train Loss: 2.14933 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [28/50]: Avg. Train Loss: 2.13755 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [29/50]: Avg. Train Loss: 2.10372 | Avg. Non-Zero Triplets: 41818.00000
# Epoch [30/50]: Avg. Train Loss: 2.06136 | Avg. Non-Zero Triplets: 41714.50000
# Epoch [31/50]: Avg. Train Loss: 2.12900 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [32/50]: Avg. Train Loss: 2.07958 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [33/50]: Avg. Train Loss: 2.07494 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [34/50]: Avg. Train Loss: 2.22262 | Avg. Non-Zero Triplets: 40931.00000
# Epoch [35/50]: Avg. Train Loss: 2.36418 | Avg. Non-Zero Triplets: 40800.50000
# Epoch [36/50]: Avg. Train Loss: 2.26918 | Avg. Non-Zero Triplets: 41326.00000
# Epoch [37/50]: Avg. Train Loss: 2.22108 | Avg. Non-Zero Triplets: 40892.00000
# Epoch [38/50]: Avg. Train Loss: 2.07591 | Avg. Non-Zero Triplets: 41529.00000
# Epoch [39/50]: Avg. Train Loss: 1.99758 | Avg. Non-Zero Triplets: 41528.00000
# Epoch [40/50]: Avg. Train Loss: nan | Avg. Non-Zero Triplets: 41006.50000
# Epoch [41/50]: Avg. Train Loss: 2.11918 | Avg. Non-Zero Triplets: 37898.00000
# Epoch [42/50]: Avg. Train Loss: 2.12241 | Avg. Non-Zero Triplets: 35991.00000
# Epoch [43/50]: Avg. Train Loss: 2.28786 | Avg. Non-Zero Triplets: 38549.00000
# Epoch [44/50]: Avg. Train Loss: 2.20390 | Avg. Non-Zero Triplets: 34443.00000
# Epoch [45/50]: Avg. Train Loss: 2.07470 | Avg. Non-Zero Triplets: 35043.50000
# Epoch [46/50]: Avg. Train Loss: 2.11927 | Avg. Non-Zero Triplets: 38251.50000
# Epoch [47/50]: Avg. Train Loss: 2.05957 | Avg. Non-Zero Triplets: 38509.00000
# Epoch [48/50]: Avg. Train Loss: 2.16007 | Avg. Non-Zero Triplets: 36244.00000
# Epoch [49/50]: Avg. Train Loss: 2.20526 | Avg. Non-Zero Triplets: 37926.00000
# Epoch [50/50]: Avg. Train Loss: 2.16224 | Avg. Non-Zero Triplets: 36549.00000
# Epoch [51/500]: Avg. Train Loss: 2.14360 | Avg. Non-Zero Triplets: 35517.00000
# Epoch [52/500]: Avg. Train Loss: 2.30517 | Avg. Non-Zero Triplets: 34657.50000
# Epoch [53/500]: Avg. Train Loss: 2.30543 | Avg. Non-Zero Triplets: 32467.50000
# Epoch [54/500]: Avg. Train Loss: 2.13612 | Avg. Non-Zero Triplets: 34664.50000
# Epoch [55/500]: Avg. Train Loss: 2.12896 | Avg. Non-Zero Triplets: 41114.50000
# Epoch [56/500]: Avg. Train Loss: 2.25416 | Avg. Non-Zero Triplets: 39067.00000
# Epoch [57/500]: Avg. Train Loss: 2.47341 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [58/500]: Avg. Train Loss: 2.47880 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [59/500]: Avg. Train Loss: 2.45465 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [60/500]: Avg. Train Loss: 2.23636 | Avg. Non-Zero Triplets: 41505.00000
# Epoch [61/500]: Avg. Train Loss: 2.30145 | Avg. Non-Zero Triplets: 41818.00000
# Epoch [62/500]: Avg. Train Loss: 2.19717 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [63/500]: Avg. Train Loss: 2.33146 | Avg. Non-Zero Triplets: 41730.00000
# Epoch [64/500]: Avg. Train Loss: 2.34989 | Avg. Non-Zero Triplets: 41817.00000
# Epoch [65/500]: Avg. Train Loss: 2.38666 | Avg. Non-Zero Triplets: 40092.00000
# Epoch [66/500]: Avg. Train Loss: 2.30309 | Avg. Non-Zero Triplets: 41394.00000
# Epoch [67/500]: Avg. Train Loss: 2.36037 | Avg. Non-Zero Triplets: 38762.00000
# Epoch [68/500]: Avg. Train Loss: 2.35127 | Avg. Non-Zero Triplets: 38995.50000

# %% [markdown]
# ## Training Loss Plot

# %%
fig, ax = plt.subplots(figsize=(15,4))
ax.plot(dict_train_loss.keys(), dict_train_loss.values(), marker="o", label="Training Loss")
ax.set_xlabel("Epoch")
ax.set_ylabel("Training Loss")
ax.grid()
ax.legend();

# %% [markdown]
# ## Trained Embeddings after 50 Epochs

# %%
model = load_model("nonlinear_triplet_norm_net_50.pt")

train_embeddings, train_labels = extract_embedding(train_loader, model, use_cuda)
fig, ax = plt.subplots(figsize=(6,6))
plot_2d_circle()
plot_2d_embedding(train_embeddings, 
                  train_labels, 
                  ax=ax, xlim=[-1.5, 1.5], 
                  ylim=[-1.5, 1.5])

# %% [markdown]
# ## Trained Embeddings after 500 Epochs

# %%
model = load_model("nonlinear_triplet_norm_net_500.pt")

train_embeddings, train_labels = extract_embedding(train_loader, model, use_cuda)
fig, ax = plt.subplots(figsize=(6,6))
plot_2d_circle()
plot_2d_embedding(train_embeddings, 
                  train_labels, 
                  ax=ax, xlim=[-1.5, 1.5], 
                  ylim=[-1.5, 1.5])

# %% [markdown]
# ## Trained Embeddings after 1000 Epochs

# %%
model = load_model("nonlinear_triplet_norm_net_1000.pt")

train_embeddings, train_labels = extract_embedding(train_loader, model, use_cuda)
fig, ax = plt.subplots(figsize=(6,6))
plot_2d_circle()
plot_2d_embedding(train_embeddings, 
                  train_labels, 
                  ax=ax, xlim=[-1.5, 1.5], 
                  ylim=[-1.5, 1.5])
