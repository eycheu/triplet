# %%
# Load IPython extension to reload modules
# %load_ext autoreload
# Reload all modules (except those excluded by %aimport) every time before executing the Python code typed.
# %autoreload 2

# %%
import sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline

import torch
from torch.utils.data import DataLoader
# from torch.optim import lr_scheduler
# Out:
# /mnt/ey/conda_envs/py3.6.3_env1/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /mnt/ey/conda_envs/py3.6.3_env1/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
sys.path.append("../src/")
from dataset import DummyDataset
from network import NormEmbeddingNet, NormClampEmbeddingNet, extract_embedding
from loss import OnlineTripletLoss, OnlineNonLinearTripletLoss
from metric import AverageNonZeroTripletsMetric
from trainer import fit
from sampler import BalancedBatchSampler, SemiHardNegativeTripletSelector, MarginallyHardNegativeTripletSelector
from display import plot_image, plot_2d_circle, plot_2d_embedding

# %% [markdown]
# ## Non-Linear Triplet Associative-Contrastive Loss Function
# $Loss = -ln\left(1-\frac{||Z^a-Z^p||_2}{\beta_1}+\epsilon\right) -ln\left(1-\frac{D-||Z^a-Z^n||_2}{\beta_2}+\epsilon\right)$
# - Associative loss is minimised when distance between two data points of the same class (anchor-postive) is minimised.
# - Contrastive loss is minimised when distance between two data points of the different classes (anchor-negative) is maximised.

# %%
beta1 = 2
beta2 = 2.01
max_dist = 2
d = np.array([v for v in np.arange(0, max_dist, 0.01)])
y1 = -np.log(1-(d/beta1)+1e-8)
y2 = -np.log(1 -((max_dist-d)/beta2)+1e-8)

fig, axes = plt.subplots(1, 3, figsize=(12,4))
ax = axes.item(0)
ax.plot(d, y1, label=r"$-ln\left(1-\frac{||Z^a-Z^p||_2}{\beta_1} + \epsilon\right)$", linewidth=2)
ax.set_title(r"$\beta_1 = {}$".format(beta1))
ax.set_xlabel(r"Anchor-Positive Distance: $||Z^a-Z^p||_2$")
ax.set_ylabel(r"Anchor-Positive Loss")
ax.grid()
ax.legend()

ax = axes.item(1)
ax.plot(d, y2, label=r"$-ln\left(1-\frac{D-||Z^a-Z^n||_2}{\beta_2} + \epsilon\right)$", linewidth=2)
ax.set_title(r"$\beta_2 = {}$, $D = {}$".format(beta2, max_dist))
ax.set_xlabel(r"Anchor-Negative Distance: $||Z^a-Z^n||_2$")
ax.set_ylabel(r"Anchor-Negative Loss")
ax.grid()
ax.legend()

ax = axes.item(2)
ax.plot(d, y1, label=r"$-ln\left(1-\frac{||Z^a-Z^p||_2}{\beta_1} + \epsilon\right)$", linewidth=2)
ax.plot(d, y2, label=r"$-ln\left(1-\frac{d-||Z^a-Z^n||_2}{\beta_2} + \epsilon\right)$", linewidth=2)
ax.grid()
ax.legend()
fig.tight_layout()

# %% [markdown]
# ## Load Dummy Dataset

# %%
ds_dummy = DummyDataset()
# Out:
# Loading Dummy Dataset ...
# Class distribution:
# 0    1000
# 1     136
# Name: class, dtype: int64
# Number of signals: 9
# Number of signal steps: 29
# Number of records: 1136

# %% [markdown]
# ### Examples of Class 0

# %%
for i in range(500, 510):
    data = ds_dummy.__getitem__(i)[0]
    target = ds_dummy.__getitem__(i)[1]
    plot_image(data, target)

# %% [markdown]
# ### Examples of Class 1

# %%
for i in range(0, 10):
    data = ds_dummy.__getitem__(i)[0]
    target = ds_dummy.__getitem__(i)[1]
    plot_image(data, target)

# %%
dict_args = dict()
dict_args["batch_size"] = 256
dict_args["no_cuda"] = False
dict_args["optimizer"] = "Adam"
dict_args["lr"] = 1e-2
dict_args["epochs"] = 50
dict_args["margin"] = 0.5
dict_args["log_interval"] = None
dict_args["seed"] = 1

use_cuda = not dict_args["no_cuda"] and torch.cuda.is_available()

torch.manual_seed(dict_args["seed"])

device = torch.device("cuda" if use_cuda else "cpu")

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

print("use_cuda :", use_cuda)
print("device :", device)
# Out:
# use_cuda : False
# device : cpu

# %%
train_loader = DataLoader(ds_dummy, 
                         batch_size=dict_args["batch_size"], 
                         shuffle=False, **kwargs)

for batch_idx, (data, target) in enumerate(train_loader):
    print(data.shape, target.shape)
    break

train_batch_sampler = BalancedBatchSampler(ds_dummy, n_classes=2, n_samples=256)
online_train_loader = DataLoader(ds_dummy, batch_sampler=train_batch_sampler, **kwargs)

for batch_idx, (data, target) in enumerate(online_train_loader):
    print(data.shape, target.shape)
    break
# Out:
# torch.Size([256, 1, 9, 29]) torch.Size([256])
# torch.Size([392, 1, 9, 29]) torch.Size([392])

# %%
# Select negative point when ap_distance + margin > an_distance 
loss_fn = OnlineNonLinearTripletLoss(MarginallyHardNegativeTripletSelector(dict_args["margin"]),
                                     max_dist=2,
                                     beta1=2,
                                     beta2=2.01,
                                     epsilon=1e-8)

# %%
# loss_fn = OnlineTripletLoss(dict_args["margin"], SemihardNegativeTripletSelector(dict_args["margin"]))

# %%
# loss_fn = OnlineNonLinearTripletLoss(SemiHardNegativeTripletSelector(dict_args["margin"]),
#                                      max_dist=2,
#                                      beta1=2,
#                                      beta2=2.01,
#                                      epsilon=1e-8)

# %%
def load_model(path=None):
    model = NormClampEmbeddingNet([1, 50, 20], 
                               ds_dummy.n_grps, 
                               ds_dummy.n_steps,
                               kernel_size=3, 
                               dropout=0.1,
                               fc_nodes=[50, 50, 2],
                               p=2)
    if path is not None:
        model.load_state_dict(torch.load(path))
    return model

model = load_model(None)
model = model.to(device)

# %%
#loss_fn = TripletLoss(dict_args["margin"])
optimizer = getattr(torch.optim, dict_args["optimizer"])(model.parameters(), lr=dict_args["lr"])
# scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)

# %% [markdown]
# ## Initial Embeddings

# %%
train_embeddings, train_labels = extract_embedding(train_loader, model, use_cuda)
fig, ax = plt.subplots(figsize=(6,6))
plot_2d_circle(ax)
plot_2d_embedding(train_embeddings, 
                  train_labels, 
                  ax=ax, xlim=[-1.5, 1.5], 
                  ylim=[-1.5, 1.5])

# %% [markdown]
# ## Plot Embeddings
# Plot embeddings after every training epoch

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(12, 4)) 
gs = gridspec.GridSpec(1, 2, width_ratios=[1, 2]) 
ax0 = plt.subplot(gs[0])
ax1 = plt.subplot(gs[1])
fig.tight_layout()
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="863.8889117741296">

# %%
dict_train_loss = {}
n_epochs = 100
epoch = 0

# %%
while epoch < n_epochs:
    tmp_dict_train_loss, _ = fit(online_train_loader, 
                                         None, 
                                         model, 
                                         loss_fn, 
                                         optimizer, None, 
                                         epoch+1, 
                                         use_cuda, 
                                         dict_args["log_interval"], 
                                         metrics=[AverageNonZeroTripletsMetric()],
                                         start_epoch=epoch)
    dict_train_loss.update(tmp_dict_train_loss)
    
    train_embeddings, train_labels = extract_embedding(train_loader, model, use_cuda)
    
    ax = ax0
    ax.cla()
    plot_2d_circle(ax)
    plot_2d_embedding(train_embeddings, 
                  train_labels, 
                  ax=ax, xlim=[-1.5, 1.5], 
                  ylim=[-1.5, 1.5])
    
    ax.set_title("Epoch {}/{} : {:.5f}".format(epoch+1, n_epochs, tmp_dict_train_loss[epoch+1]))
    
    ax = ax1
    ax.cla()
    ax.plot(dict_train_loss.keys(), dict_train_loss.values(), marker="o", label="Training Loss")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Training Loss")
    ax.set_xlim([0, n_epochs])
    ax.grid()
    ax.legend();
    
    fig.canvas.draw()
    epoch += 1
# Out:
# Epoch [1/1]: Avg. Train Loss: 2.36429 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [2/2]: Avg. Train Loss: 2.40744 | Avg. Non-Zero Triplets: 41819.50000
# Epoch [3/3]: Avg. Train Loss: 2.14227 | Avg. Non-Zero Triplets: 41819.50000
# Epoch [4/4]: Avg. Train Loss: 1.82716 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [5/5]: Avg. Train Loss: 1.87390 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [6/6]: Avg. Train Loss: 1.96623 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [7/7]: Avg. Train Loss: 1.83763 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [8/8]: Avg. Train Loss: 1.83480 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [9/9]: Avg. Train Loss: 1.79930 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [10/10]: Avg. Train Loss: 1.81314 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [11/11]: Avg. Train Loss: 1.80959 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [12/12]: Avg. Train Loss: 1.79109 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [13/13]: Avg. Train Loss: 1.75279 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [14/14]: Avg. Train Loss: 1.73984 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [15/15]: Avg. Train Loss: 1.72772 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [16/16]: Avg. Train Loss: 1.79376 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [17/17]: Avg. Train Loss: 1.69987 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [18/18]: Avg. Train Loss: 1.74964 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [19/19]: Avg. Train Loss: 1.75197 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [20/20]: Avg. Train Loss: 1.70834 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [21/21]: Avg. Train Loss: 1.73653 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [22/22]: Avg. Train Loss: 1.79081 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [23/23]: Avg. Train Loss: 1.70277 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [24/24]: Avg. Train Loss: 1.66552 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [25/25]: Avg. Train Loss: 1.65018 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [26/26]: Avg. Train Loss: 1.63789 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [27/27]: Avg. Train Loss: 1.69748 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [28/28]: Avg. Train Loss: 1.66873 | Avg. Non-Zero Triplets: 41820.00000

# %% [markdown]
# ## Train Model

# %%
dict_train_loss = {}
list_end_epochs = [50, 500, 1000]
start_epoch = 0
for i, end_epoch in enumerate(list_end_epochs):
    tmp_dict_train_loss, _ = fit(online_train_loader, 
                                         None, 
                                         model, 
                                         loss_fn, 
                                         optimizer, None, 
                                         end_epoch, 
                                         use_cuda, 
                                         dict_args["log_interval"], 
                                         metrics=[AverageNonZeroTripletsMetric()],
                                         start_epoch=start_epoch)
    
    # torch.save(model.state_dict(), "nonlinear_triplet_norm_clamp_net_{}.pt".format(end_epoch))
    
    start_epoch = end_epoch
    
    dict_train_loss.update(tmp_dict_train_loss)
# Out:
# Epoch [1/50]: Avg. Train Loss: 2.27006 | Avg. Non-Zero Triplets: 41820.00000
# Epoch
# Epoch [352/500]: Avg. Train Loss: 1.63913 | Avg. Non-Zero Triplets: 112.50000
# Epoch [353/500]: Avg. Train Loss: 0.03007 | Avg. Non-Zero Triplets: 1.00000
# Epoch [354/500]: Avg. Train Loss: 1.05715 | Avg. Non-Zero Triplets: 4718.00000
# Epoch [355/500]: Avg. Train Loss: 0.04889 | Avg. Non-Zero Triplets: 1.00000
# Epoch [356/500]: Avg. Train Loss: 0.60107 | Avg. Non-Zero Triplets: 17.00000
# Epoch [357/500]: Avg. Train Loss: 0.91258 | Avg. Non-Zero Triplets: 195.00000
# Epoch [358/500]: Avg. Train Loss: 0.73103 | Avg. Non-Zero Triplets: 167.00000
# Epoch [359/500]: Avg. Train Loss: 1.07138 | Avg. Non-Zero Triplets: 96.50000
# Epoch [360/500]: Avg. Train Loss: 0.10259 | Avg. Non-Zero Triplets: 1.00000
# Epoch [361/500]: Avg. Train Loss: 0.73296 | Avg. Non-Zero Triplets: 4693.50000
# Epoch [362/500]: Avg. Train Loss: 0.01250 | Avg. Non-Zero Triplets: 1.00000
# Epoch [363/500]: Avg. Train Loss: 0.29000 | Avg. Non-Zero Triplets: 1.00000
# Epoch [364/500]: Avg. Train Loss: 0.67404 | Avg. Non-Zero Triplets: 9.50000
# Epoch [365/500]: Avg. Train Loss: 0.12966 | Avg. Non-Zero Triplets: 1.00000
# Epoch [366/500]: Avg. Train Loss: 0.11872 | Avg. Non-Zero Triplets: 1.00000
# Epoch [367/500]: Avg. Train Loss: 0.07123 | Avg. Non-Zero Triplets: 1.00000
# Epoch [368/500]: Avg. Train Loss: 0.08409 | Avg. Non-Zero Triplets: 1.00000
# Epoch [369/500]: Avg. Train Loss: 0.78352 | Avg. Non-Zero Triplets: 3.00000
# Epoch [370/500]: Avg. Train Loss: 0.10684 | Avg. Non-Zero Triplets: 1.00000
# Epoch [371/500]: Avg. Train Loss: 0.12676 | Avg. Non-Zero Triplets: 1.00000
# Epoch [372/500]: Avg. Train Loss: 0.62697 | Avg. Non-Zero Triplets: 2955.00000
# Epoch [373/500]: Avg. Train Loss: 0.06451 | Avg. Non-Zero Triplets: 1.00000
# Epoch [374/500]: Avg. Train Loss: 0.10404 | Avg. Non-Zero Triplets: 1.00000
# Epoch [375/500]: Avg. Train Loss: 0.05741 | Avg. Non-Zero Triplets: 1.00000
# Epoch [376/500]: Avg. Train Loss: 0.06868 | Avg. Non-Zero Triplets: 1.00000
# Epoch [377/500]: Avg. Train Loss: 0.05753 | Avg. Non-Zero Triplets: 1.00000
# Epoch [378/500]: Avg. Train Loss: 0.76494 | Avg. Non-Zero Triplets: 69.50000
# Epoch [379/500]: Avg. Train Loss: 0.04596 | Avg. Non-Zero Triplets: 1.00000
# Epoch [380/500]: Avg. Train Loss: 0.03724 | Avg. Non-Zero Triplets: 1.00000
# Epoch [381/500]: Avg. Train Loss: 0.03170 | Avg. Non-Zero Triplets: 1.00000
# Epoch [382/500]: Avg. Train Loss: 0.04030 | Avg. Non-Zero Triplets: 1.00000
# Epoch [383/500]: Avg. Train Loss: 0.02117 | Avg. Non-Zero Triplets: 1.00000
# Epoch [384/500]: Avg. Train Loss: 2.07847 | Avg. Non-Zero Triplets: 4845.50000
# Epoch [385/500]: Avg. Train Loss: 0.02312 | Avg. Non-Zero Triplets: 1.00000
# Epoch [386/500]: Avg. Train Loss: 0.03544 | Avg. Non-Zero Triplets: 1.00000
# Epoch [387/500]: Avg. Train Loss: 0.02880 | Avg. Non-Zero Triplets: 1.00000
# Epoch [388/500]: Avg. Train Loss: 0.07307 | Avg. Non-Zero Triplets: 1.00000
# Epoch [389/500]: Avg. Train Loss: 0.64363 | Avg. Non-Zero Triplets: 57.50000
# Epoch [390/500]: Avg. Train Loss: 0.15108 | Avg. Non-Zero Triplets: 1.00000
# Epoch [391/500]: Avg. Train Loss: 0.09510 | Avg. Non-Zero Triplets: 1.00000
# Epoch [392/500]: Avg. Train Loss: 0.66443 | Avg. Non-Zero Triplets: 366.00000
# Epoch [393/500]: Avg. Train Loss: 0.73540 | Avg. Non-Zero Triplets: 993.00000
# Epoch [394/500]: Avg. Train Loss: 0.79449 | Avg. Non-Zero Triplets: 4718.00000
# Epoch [395/500]: Avg. Train Loss: 0.08667 | Avg. Non-Zero Triplets: 1.00000
# Epoch [396/500]: Avg. Train Loss: 0.08270 | Avg. Non-Zero Triplets: 1.00000
# Epoch [397/500]: Avg. Train Loss: 0.03700 | Avg. Non-Zero Triplets: 1.00000
# Epoch [398/500]: Avg. Train Loss: 0.05118 | Avg. Non-Zero Triplets: 1.00000
# Epoch [399/500]: Avg. Train Loss: 0.92029 | Avg. Non-Zero Triplets: 9.00000
# Epoch [400/500]: Avg. Train Loss: 0.62291 | Avg. Non-Zero Triplets: 6.50000
# Epoch [401/500]: Avg. Train Loss: 1.17527 | Avg. Non-Zero Triplets: 84.50000
# Epoch [402/500]: Avg. Train Loss: 0.02651 | Avg. Non-Zero Triplets: 1.00000
# Epoch [403/500]: Avg. Train Loss: 0.02826 | Avg. Non-Zero Triplets: 1.00000
# Epoch [404/500]: Avg. Train Loss: 0.04905 | Avg. Non-Zero Triplets: 1.00000
# Epoch [405/500]: Avg. Train Loss: 0.06395 | Avg. Non-Zero Triplets: 1.00000
# Epoch [406/500]: Avg. Train Loss: 0.71733 | Avg. Non-Zero Triplets: 246.50000
# Epoch [407/500]: Avg. Train Loss: 0.03269 | Avg. Non-Zero Triplets: 1.00000
# Epoch [408/500]: Avg. Train Loss: 0.01058 | Avg. Non-Zero Triplets: 1.00000
# Epoch [409/500]: Avg. Train Loss: 0.02360 | Avg. Non-Zero Triplets: 1.00000
# Epoch [410/500]: Avg. Train Loss: 0.01362 | Avg. Non-Zero Triplets: 1.00000
# Epoch [411/500]: Avg. Train Loss: 1.58548 | Avg. Non-Zero Triplets: 16397.50000
# Epoch [412/500]: Avg. Train Loss: 0.01209 | Avg. Non-Zero Triplets: 1.00000
# Epoch [413/500]: Avg. Train Loss: 0.00715 | Avg. Non-Zero Triplets: 1.00000
# Epoch [445/500]: Avg. Train Loss: 0.59248 | Avg. Non-Zero Triplets: 11.50000
# Epoch [446/500]: Avg. Train Loss: 0.02455 | Avg. Non-Zero Triplets: 1.00000
# Epoch [447/500]: Avg. Train Loss: 0.00559 | Avg. Non-Zero Triplets: 1.00000
# Epoch [448/500]: Avg. Train Loss: 0.73900 | Avg. Non-Zero Triplets: 115.50000
# Epoch [449/500]: Avg. Train Loss: 0.55168 | Avg. Non-Zero Triplets: 16363.50000
# Epoch [450/500]: Avg. Train Loss: 0.04788 | Avg. Non-Zero Triplets: 1.00000
# Epoch [451/500]: Avg. Train Loss: 0.02241 | Avg. Non-Zero Triplets: 1.00000
# Epoch [452/500]: Avg. Train Loss: 0.37831 | Avg. Non-Zero Triplets: 1.00000
# Epoch [453/500]: Avg. Train Loss: 0.70189 | Avg. Non-Zero Triplets: 48.50000
# Epoch [454/500]: Avg. Train Loss: 0.01682 | Avg. Non-Zero Triplets: 1.00000
# Epoch [455/500]: Avg. Train Loss: 0.01921 | Avg. Non-Zero Triplets: 1.00000
# Epoch [456/500]: Avg. Train Loss: 0.06203 | Avg. Non-Zero Triplets: 1.00000
# Epoch [457/500]: Avg. Train Loss: 2.31785 | Avg. Non-Zero Triplets: 4934.00000
# Epoch [458/500]: Avg. Train Loss: 0.65712 | Avg. Non-Zero Triplets: 96.00000
# Epoch [459/500]: Avg. Train Loss: 2.33988 | Avg. Non-Zero Triplets: 21119.50000
# Epoch [460/500]: Avg. Train Loss: 2.58005 | Avg. Non-Zero Triplets: 32946.50000
# Epoch [461/500]: Avg. Train Loss: 1.96161 | Avg. Non-Zero Triplets: 33035.00000
# Epoch [462/500]: Avg. Train Loss: 1.53803 | Avg. Non-Zero Triplets: 33223.50000
# Epoch [463/500]: Avg. Train Loss: 1.25968 | Avg. Non-Zero Triplets: 140.00000
# Epoch [464/500]: Avg. Train Loss: 0.68712 | Avg. Non-Zero Triplets: 201.00000
# Epoch [465/500]: Avg. Train Loss: 0.66821 | Avg. Non-Zero Triplets: 19.00000
# Epoch [466/500]: Avg. Train Loss: 0.04850 | Avg. Non-Zero Triplets: 1.00000
# Epoch [467/500]: Avg. Train Loss: 1.30478 | Avg. Non-Zero Triplets: 189.50000
# Epoch [468/500]: Avg. Train Loss: 0.03603 | Avg. Non-Zero Triplets: 1.00000
# Epoch [469/500]: Avg. Train Loss: 0.67004 | Avg. Non-Zero Triplets: 13.50000
# Epoch [470/500]: Avg. Train Loss: 0.04696 | Avg. Non-Zero Triplets: 1.00000
# Epoch [471/500]: Avg. Train Loss: 0.01760 | Avg. Non-Zero Triplets: 1.00000
# Epoch [472/500]: Avg. Train Loss: 0.02549 | Avg. Non-Zero Triplets: 1.00000
# Epoch [473/500]: Avg. Train Loss: 0.07993 | Avg. Non-Zero Triplets: 1.00000
# Epoch [474/500]: Avg. Train Loss: 0.58531 | Avg. Non-Zero Triplets: 117.50000
# Epoch [475/500]: Avg. Train Loss: 0.04076 | Avg. Non-Zero Triplets: 1.00000
# Epoch [476/500]: Avg. Train Loss: 0.03897 | Avg. Non-Zero Triplets: 1.00000
# Epoch [477/500]: Avg. Train Loss: 0.59715 | Avg. Non-Zero Triplets: 38.50000
# Epoch [478/500]: Avg. Train Loss: 0.01907 | Avg. Non-Zero Triplets: 1.00000
# Epoch [479/500]: Avg. Train Loss: 0.04770 | Avg. Non-Zero Triplets: 1.00000
# Epoch [480/500]: Avg. Train Loss: 0.69098 | Avg. Non-Zero Triplets: 4718.00000
# Epoch [481/500]: Avg. Train Loss: 0.03098 | Avg. Non-Zero Triplets: 1.00000
# Epoch [482/500]: Avg. Train Loss: 0.02041 | Avg. Non-Zero Triplets: 1.00000
# Epoch [483/500]: Avg. Train Loss: 0.01396 | Avg. Non-Zero Triplets: 1.00000
# Epoch [484/500]: Avg. Train Loss: 1.44565 | Avg. Non-Zero Triplets: 16470.00000
# Epoch [485/500]: Avg. Train Loss: 0.10620 | Avg. Non-Zero Triplets: 1.00000
# Epoch [486/500]: Avg. Train Loss: 0.02021 | Avg. Non-Zero Triplets: 1.00000
# Epoch [487/500]: Avg. Train Loss: 0.68696 | Avg. Non-Zero Triplets: 9.50000
# Epoch [488/500]: Avg. Train Loss: 0.86040 | Avg. Non-Zero Triplets: 250.50000
# Epoch [489/500]: Avg. Train Loss: 0.63296 | Avg. Non-Zero Triplets: 61.50000
# Epoch [490/500]: Avg. Train Loss: 0.02809 | Avg. Non-Zero Triplets: 1.00000
# Epoch [491/500]: Avg. Train Loss: 0.64267 | Avg. Non-Zero Triplets: 69.00000
# Epoch [492/500]: Avg. Train Loss: 0.02567 | Avg. Non-Zero Triplets: 1.00000
# Epoch [493/500]: Avg. Train Loss: 0.01899 | Avg. Non-Zero Triplets: 1.00000
# Epoch [494/500]: Avg. Train Loss: 0.04046 | Avg. Non-Zero Triplets: 1.00000
# Epoch [495/500]: Avg. Train Loss: 0.04415 | Avg. Non-Zero Triplets: 1.00000
# Epoch [496/500]: Avg. Train Loss: 0.01813 | Avg. Non-Zero Triplets: 1.00000
# Epoch [497/500]: Avg. Train Loss: 0.04392 | Avg. Non-Zero Triplets: 1.00000
# Epoch [498/500]: Avg. Train Loss: 0.08314 | Avg. Non-Zero Triplets: 1.00000
# Epoch [499/500]: Avg. Train Loss: 0.71905 | Avg. Non-Zero Triplets: 141.50000
# Epoch [500/500]: Avg. Train Loss: 0.03354 | Avg. Non-Zero Triplets: 1.00000
# Epoch [501/1000]: Avg. Train Loss: 0.02617 | Avg. Non-Zero Triplets: 1.00000
# Epoch [502/1000]: Avg. Train Loss: 0.03740 | Avg. Non-Zero Triplets: 1.00000
# Epoch [503/1000]: Avg. Train Loss: 0.01974 | Avg. Non-Zero Triplets: 1.00000
# Epoch [504/1000]: Avg. Train Loss: 0.02751 | Avg. Non-Zero Triplets: 1.00000
# Epoch [505/1000]: Avg. Train Loss: 0.03353 | Avg. Non-Zero Triplets: 1.00000
# Epoch [506/1000]: Avg. Train Loss: 0.02862 | Avg. Non-Zero Triplets: 1.00000
# Epoch [507/1000]: Avg. Train Loss: 0.02227 | Avg. Non-Zero Triplets: 1.00000
# Epoch [508/1000]: Avg. Train Loss: 0.00344 | Avg. Non-Zero Triplets: 1.00000
# Epoch [509/1000]: Avg. Train Loss: 0.01491 | Avg. Non-Zero Triplets: 1.00000
# Epoch [510/1000]: Avg. Train Loss: 0.01258 | Avg. Non-Zero Triplets: 1.00000
# Epoch [511/1000]: Avg. Train Loss: 0.02030 | Avg. Non-Zero Triplets: 1.00000
# Epoch [512/1000]: Avg. Train Loss: 0.02755 | Avg. Non-Zero Triplets: 1.00000
# Epoch [513/1000]: Avg. Train Loss: 0.00355 | Avg. Non-Zero Triplets: 1.00000
# Epoch [514/1000]: Avg. Train Loss: 0.01365 | Avg. Non-Zero Triplets: 1.00000
# Epoch [515/1000]: Avg. Train Loss: 0.00577 | Avg. Non-Zero Triplets: 1.00000
# Epoch [516/1000]: Avg. Train Loss: 0.07452 | Avg. Non-Zero Triplets: 1.00000
# Epoch [517/1000]: Avg. Train Loss: 0.70008 | Avg. Non-Zero Triplets: 115.00000
# Epoch [518/1000]: Avg. Train Loss: 0.02034 | Avg. Non-Zero Triplets: 1.00000
# Epoch [519/1000]: Avg. Train Loss: 0.01331 | Avg. Non-Zero Triplets: 1.00000
# Epoch [520/1000]: Avg. Train Loss: 0.01475 | Avg. Non-Zero Triplets: 1.00000
# Epoch [521/1000]: Avg. Train Loss: 0.88494 | Avg. Non-Zero Triplets: 16356.00000
# Epoch [522/1000]: Avg. Train Loss: 0.82686 | Avg. Non-Zero Triplets: 244.50000
# Epoch [523/1000]: Avg. Train Loss: 0.00864 | Avg. Non-Zero Triplets: 1.00000
# Epoch [524/1000]: Avg. Train Loss: 0.01782 | Avg. Non-Zero Triplets: 1.00000
# Epoch [525/1000]: Avg. Train Loss: 0.02006 | Avg. Non-Zero Triplets: 1.00000
# Epoch [526/1000]: Avg. Train Loss: 0.01787 | Avg. Non-Zero Triplets: 1.00000
# Epoch [527/1000]: Avg. Train Loss: 1.27393 | Avg. Non-Zero Triplets: 21055.00000
# Epoch [528/1000]: Avg. Train Loss: 0.57650 | Avg. Non-Zero Triplets: 6.50000
# Epoch [529/1000]: Avg. Train Loss: 0.00571 | Avg. Non-Zero Triplets: 1.00000
# Epoch [530/1000]: Avg. Train Loss: 0.59964 | Avg. Non-Zero Triplets: 52.00000
# Epoch [531/1000]: Avg. Train Loss: 0.58838 | Avg. Non-Zero Triplets: 158.50000
# Epoch [532/1000]: Avg. Train Loss: 0.01416 | Avg. Non-Zero Triplets: 1.00000
# Epoch [533/1000]: Avg. Train Loss: 0.02282 | Avg. Non-Zero Triplets: 1.00000
# Epoch [534/1000]: Avg. Train Loss: 0.64991 | Avg. Non-Zero Triplets: 36.50000
# Epoch [535/1000]: Avg. Train Loss: 0.85419 | Avg. Non-Zero Triplets: 247.00000
# Epoch [536/1000]: Avg. Train Loss: 0.02259 | Avg. Non-Zero Triplets: 1.00000
# Epoch [537/1000]: Avg. Train Loss: 0.02419 | Avg. Non-Zero Triplets: 1.00000
# Epoch [538/1000]: Avg. Train Loss: 0.72693 | Avg. Non-Zero Triplets: 4704.50000
# Epoch [539/1000]: Avg. Train Loss: 1.32189 | Avg. Non-Zero Triplets: 176.50000
# Epoch [540/1000]: Avg. Train Loss: 0.02354 | Avg. Non-Zero Triplets: 1.00000
# Epoch [541/1000]: Avg. Train Loss: 0.01801 | Avg. Non-Zero Triplets: 1.00000
# Epoch [542/1000]: Avg. Train Loss: 0.66265 | Avg. Non-Zero Triplets: 31.00000
# Epoch [543/1000]: Avg. Train Loss: 1.88829 | Avg. Non-Zero Triplets: 4724.50000
# Epoch [544/1000]: Avg. Train Loss: 0.03352 | Avg. Non-Zero Triplets: 1.00000
# Epoch [545/1000]: Avg. Train Loss: 0.64779 | Avg. Non-Zero Triplets: 77.00000
# Epoch [546/1000]: Avg. Train Loss: 0.03530 | Avg. Non-Zero Triplets: 1.00000
# Epoch [547/1000]: Avg. Train Loss: 0.58372 | Avg. Non-Zero Triplets: 52.50000
# Epoch [548/1000]: Avg. Train Loss: 0.62413 | Avg. Non-Zero Triplets: 4606.00000
# Epoch [549/1000]: Avg. Train Loss: 0.70900 | Avg. Non-Zero Triplets: 36.50000
# Epoch [550/1000]: Avg. Train Loss: 0.85784 | Avg. Non-Zero Triplets: 328.50000
# Epoch [551/1000]: Avg. Train Loss: 0.07027 | Avg. Non-Zero Triplets: 1.00000
# Epoch [552/1000]: Avg. Train Loss: 0.03090 | Avg. Non-Zero Triplets: 1.00000
# Epoch [553/1000]: Avg. Train Loss: 0.08966 | Avg. Non-Zero Triplets: 1.00000
# Epoch [554/1000]: Avg. Train Loss: 0.59721 | Avg. Non-Zero Triplets: 22.50000
# Epoch [555/1000]: Avg. Train Loss: 0.02732 | Avg. Non-Zero Triplets: 1.00000
# Epoch [556/1000]: Avg. Train Loss: 0.05421 | Avg. Non-Zero Triplets: 1.00000
# Epoch [557/1000]: Avg. Train Loss: 0.03543 | Avg. Non-Zero Triplets: 1.00000
# Epoch [558/1000]: Avg. Train Loss: 0.00596 | Avg. Non-Zero Triplets: 1.00000
# Epoch [559/1000]: Avg. Train Loss: 0.00994 | Avg. Non-Zero Triplets: 1.00000
# Epoch [560/1000]: Avg. Train Loss: 0.02200 | Avg. Non-Zero Triplets: 1.00000
# Epoch [561/1000]: Avg. Train Loss: 0.86004 | Avg. Non-Zero Triplets: 16342.50000
# Epoch [562/1000]: Avg. Train Loss: 0.00611 | Avg. Non-Zero Triplets: 1.00000
# Epoch [563/1000]: Avg. Train Loss: 0.89189 | Avg. Non-Zero Triplets: 184.00000
# Epoch [564/1000]: Avg. Train Loss: 0.01778 | Avg. Non-Zero Triplets: 1.00000
# Epoch [565/1000]: Avg. Train Loss: 0.01970 | Avg. Non-Zero Triplets: 1.00000
# Epoch [566/1000]: Avg. Train Loss: 0.00859 | Avg. Non-Zero Triplets: 1.00000
# Epoch [567/1000]: Avg. Train Loss: 0.03420 | Avg. Non-Zero Triplets: 1.00000
# Epoch [568/1000]: Avg. Train Loss: 0.04573 | Avg. Non-Zero Triplets: 1.00000
# Epoch [569/1000]: Avg. Train Loss: 0.03091 | Avg. Non-Zero Triplets: 1.00000
# Epoch [570/1000]: Avg. Train Loss: 0.09927 | Avg. Non-Zero Triplets: 1.00000
# Epoch [571/1000]: Avg. Train Loss: 0.63618 | Avg. Non-Zero Triplets: 105.50000
# Epoch [572/1000]: Avg. Train Loss: 0.05223 | Avg. Non-Zero Triplets: 1.00000
# Epoch [573/1000]: Avg. Train Loss: 0.64509 | Avg. Non-Zero Triplets: 31.00000
# Epoch [574/1000]: Avg. Train Loss: 0.05946 | Avg. Non-Zero Triplets: 1.00000
# Epoch [575/1000]: Avg. Train Loss: 0.01815 | Avg. Non-Zero Triplets: 1.00000
# Epoch [576/1000]: Avg. Train Loss: 0.04986 | Avg. Non-Zero Triplets: 1.00000
# Epoch [577/1000]: Avg. Train Loss: 0.01969 | Avg. Non-Zero Triplets: 1.00000
# Epoch [578/1000]: Avg. Train Loss: 0.75119 | Avg. Non-Zero Triplets: 13.00000
# Epoch [579/1000]: Avg. Train Loss: 0.01823 | Avg. Non-Zero Triplets: 1.00000
# Epoch [580/1000]: Avg. Train Loss: 0.03951 | Avg. Non-Zero Triplets: 1.00000
# Epoch [581/1000]: Avg. Train Loss: 0.00651 | Avg. Non-Zero Triplets: 1.00000
# Epoch [582/1000]: Avg. Train Loss: 0.63726 | Avg. Non-Zero Triplets: 115.00000
# Epoch [583/1000]: Avg. Train Loss: 0.01596 | Avg. Non-Zero Triplets: 1.00000
# Epoch [584/1000]: Avg. Train Loss: 0.70202 | Avg. Non-Zero Triplets: 94.00000
# Epoch [585/1000]: Avg. Train Loss: 0.00850 | Avg. Non-Zero Triplets: 1.00000
# Epoch [586/1000]: Avg. Train Loss: 0.65543 | Avg. Non-Zero Triplets: 10.50000
# Epoch [587/1000]: Avg. Train Loss: 0.56455 | Avg. Non-Zero Triplets: 551.00000
# Epoch [588/1000]: Avg. Train Loss: 0.01291 | Avg. Non-Zero Triplets: 1.00000
# Epoch [589/1000]: Avg. Train Loss: 0.86927 | Avg. Non-Zero Triplets: 15.50000
# Epoch [590/1000]: Avg. Train Loss: 1.42117 | Avg. Non-Zero Triplets: 448.00000
# Epoch [591/1000]: Avg. Train Loss: 0.74455 | Avg. Non-Zero Triplets: 204.50000
# Epoch [592/1000]: Avg. Train Loss: 0.06649 | Avg. Non-Zero Triplets: 1.00000
# Epoch [593/1000]: Avg. Train Loss: 0.62885 | Avg. Non-Zero Triplets: 66.50000
# Epoch [594/1000]: Avg. Train Loss: 0.03960 | Avg. Non-Zero Triplets: 1.00000
# Epoch [595/1000]: Avg. Train Loss: 0.60310 | Avg. Non-Zero Triplets: 4823.50000
# Epoch [596/1000]: Avg. Train Loss: 0.65578 | Avg. Non-Zero Triplets: 52.50000
# Epoch [597/1000]: Avg. Train Loss: 0.01677 | Avg. Non-Zero Triplets: 1.00000
# Epoch [598/1000]: Avg. Train Loss: 0.61687 | Avg. Non-Zero Triplets: 18.50000
# Epoch [599/1000]: Avg. Train Loss: 0.02975 | Avg. Non-Zero Triplets: 1.00000
# Epoch [600/1000]: Avg. Train Loss: 0.02235 | Avg. Non-Zero Triplets: 1.00000
# Epoch [601/1000]: Avg. Train Loss: 0.00743 | Avg. Non-Zero Triplets: 1.00000
# Epoch [602/1000]: Avg. Train Loss: 0.01015 | Avg. Non-Zero Triplets: 1.00000
# Epoch [603/1000]: Avg. Train Loss: 0.83017 | Avg. Non-Zero Triplets: 115.00000
# Epoch [604/1000]: Avg. Train Loss: 0.00857 | Avg. Non-Zero Triplets: 1.00000
# Epoch [605/1000]: Avg. Train Loss: 0.00775 | Avg. Non-Zero Triplets: 1.00000
# Epoch [606/1000]: Avg. Train Loss: 1.16188 | Avg. Non-Zero Triplets: 16519.50000
# Epoch [607/1000]: Avg. Train Loss: 0.96046 | Avg. Non-Zero Triplets: 4718.00000
# Epoch [608/1000]: Avg. Train Loss: 0.00583 | Avg. Non-Zero Triplets: 1.00000
# Epoch [609/1000]: Avg. Train Loss: 0.00501 | Avg. Non-Zero Triplets: 1.00000
# Epoch [610/1000]: Avg. Train Loss: 0.01079 | Avg. Non-Zero Triplets: 1.00000
# Epoch [611/1000]: Avg. Train Loss: 1.47164 | Avg. Non-Zero Triplets: 204.50000
# Epoch [612/1000]: Avg. Train Loss: 0.57918 | Avg. Non-Zero Triplets: 33.50000
# Epoch [613/1000]: Avg. Train Loss: 0.02695 | Avg. Non-Zero Triplets: 1.00000
# Epoch [614/1000]: Avg. Train Loss: 0.63098 | Avg. Non-Zero Triplets: 8.50000
# Epoch [615/1000]: Avg. Train Loss: 0.02156 | Avg. Non-Zero Triplets: 1.00000
# Epoch [616/1000]: Avg. Train Loss: 0.00886 | Avg. Non-Zero Triplets: 1.00000
# Epoch [617/1000]: Avg. Train Loss: 0.00384 | Avg. Non-Zero Triplets: 1.00000
# Epoch [618/1000]: Avg. Train Loss: 0.01112 | Avg. Non-Zero Triplets: 1.00000
# Epoch [619/1000]: Avg. Train Loss: 0.00647 | Avg. Non-Zero Triplets: 1.00000
# Epoch [620/1000]: Avg. Train Loss: 0.63038 | Avg. Non-Zero Triplets: 110.50000
# Epoch [621/1000]: Avg. Train Loss: 0.66828 | Avg. Non-Zero Triplets: 46.50000
# Epoch [622/1000]: Avg. Train Loss: 0.00357 | Avg. Non-Zero Triplets: 1.00000
# Epoch [623/1000]: Avg. Train Loss: 0.02650 | Avg. Non-Zero Triplets: 1.00000
# Epoch [624/1000]: Avg. Train Loss: 0.01158 | Avg. Non-Zero Triplets: 1.00000
# Epoch [625/1000]: Avg. Train Loss: 0.00500 | Avg. Non-Zero Triplets: 1.00000
# Epoch [626/1000]: Avg. Train Loss: 0.00672 | Avg. Non-Zero Triplets: 1.00000
# Epoch [627/1000]: Avg. Train Loss: 0.00728 | Avg. Non-Zero Triplets: 1.00000
# Epoch [628/1000]: Avg. Train Loss: 0.64601 | Avg. Non-Zero Triplets: 47.00000
# Epoch [629/1000]: Avg. Train Loss: 0.01334 | Avg. Non-Zero Triplets: 1.00000
# Epoch [630/1000]: Avg. Train Loss: 0.01636 | Avg. Non-Zero Triplets: 1.00000
# Epoch [631/1000]: Avg. Train Loss: 0.01727 | Avg. Non-Zero Triplets: 1.00000
# Epoch [632/1000]: Avg. Train Loss: 0.01603 | Avg. Non-Zero Triplets: 1.00000
# Epoch [633/1000]: Avg. Train Loss: 0.00169 | Avg. Non-Zero Triplets: 1.00000
# Epoch [634/1000]: Avg. Train Loss: 0.01100 | Avg. Non-Zero Triplets: 1.00000
# Epoch [635/1000]: Avg. Train Loss: 0.00473 | Avg. Non-Zero Triplets: 1.00000
# Epoch [636/1000]: Avg. Train Loss: 0.85655 | Avg. Non-Zero Triplets: 161.00000
# Epoch [637/1000]: Avg. Train Loss: 0.00325 | Avg. Non-Zero Triplets: 1.00000
# Epoch [638/1000]: Avg. Train Loss: 0.67224 | Avg. Non-Zero Triplets: 15.00000
# Epoch [639/1000]: Avg. Train Loss: 0.60650 | Avg. Non-Zero Triplets: 4634.50000
# Epoch [640/1000]: Avg. Train Loss: 0.58224 | Avg. Non-Zero Triplets: 16378.50000
# Epoch [641/1000]: Avg. Train Loss: 0.72690 | Avg. Non-Zero Triplets: 68.00000
# Epoch [642/1000]: Avg. Train Loss: 0.01788 | Avg. Non-Zero Triplets: 1.00000
# Epoch [643/1000]: Avg. Train Loss: 0.05833 | Avg. Non-Zero Triplets: 1.00000
# Epoch [644/1000]: Avg. Train Loss: 0.09578 | Avg. Non-Zero Triplets: 1.00000

# %% [markdown]
# ## Training Loss Plot

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(15,4))
ax.plot(dict_train_loss.keys(), dict_train_loss.values(), marker="o", label="Training Loss")
ax.set_xlabel("Epoch")
ax.set_ylabel("Training Loss")
ax.grid()
ax.legend();

# %% [markdown]
# ## Trained Embeddings after 50 Epochs

# %%
# %matplotlib inline
model = load_model("nonlinear_triplet_norm_clamp_net_50.pt")

train_embeddings, train_labels = extract_embedding(train_loader, model, use_cuda)
fig, ax = plt.subplots(figsize=(6,6))
plot_2d_circle(ax)
plot_2d_embedding(train_embeddings, 
                  train_labels, 
                  ax=ax, xlim=[-1.5, 1.5], 
                  ylim=[-1.5, 1.5])

# %% [markdown]
# ## Trained Embeddings after 500 Epochs

# %%
# %matplotlib inline
model = load_model("nonlinear_triplet_norm_clamp_net_500.pt")

train_embeddings, train_labels = extract_embedding(train_loader, model, use_cuda)
fig, ax = plt.subplots(figsize=(6,6))
plot_2d_circle(ax)
plot_2d_embedding(train_embeddings, 
                  train_labels, 
                  ax=ax, xlim=[-1.5, 1.5], 
                  ylim=[-1.5, 1.5])

# %% [markdown]
# ## Trained Embeddings after 1000 Epochs

# %%
# %matplotlib inline
model = load_model("nonlinear_triplet_norm_clamp_net_1000.pt")

train_embeddings, train_labels = extract_embedding(train_loader, model, use_cuda)
fig, ax = plt.subplots(figsize=(6,6))
plot_2d_circle(ax)
plot_2d_embedding(train_embeddings, 
                  train_labels, 
                  ax=ax, xlim=[-1.5, 1.5], 
                  ylim=[-1.5, 1.5])
