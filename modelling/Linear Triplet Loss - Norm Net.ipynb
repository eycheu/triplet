# %%
# Load IPython extension to reload modules
# %load_ext autoreload
# Reload all modules (except those excluded by %aimport) every time before executing the Python code typed.
# %autoreload 2

# %%
import sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import torch
from torch.utils.data import DataLoader
# from torch.optim import lr_scheduler
# Out:
# /mnt/ey/conda_envs/py3.6.3_env1/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /mnt/ey/conda_envs/py3.6.3_env1/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
sys.path.append("../src/")
from dataset import DummyDataset
from network import NormEmbeddingNet, NormClampEmbeddingNet, extract_embedding
from loss import OnlineTripletLoss, OnlineNonLinearTripletLoss
from metric import AverageNonZeroTripletsMetric
from trainer import fit
from sampler import BalancedBatchSampler, SemiHardNegativeTripletSelector, MarginallyHardNegativeTripletSelector
from display import plot_image, plot_2d_circle, plot_2d_embedding

# %% [markdown]
# ## Load Dummy Dataset

# %%
ds_dummy = DummyDataset()
# Out:
# Loading Dummy Dataset ...
# Class distribution:
# 0    1000
# 1     136
# Name: class, dtype: int64
# Number of signals: 9
# Number of signal steps: 29
# Number of records: 1136

# %% [markdown]
# ### Examples of Class 0

# %%
for i in range(500, 510):
    data = ds_dummy.__getitem__(i)[0]
    target = ds_dummy.__getitem__(i)[1]
    plot_image(data, target)

# %% [markdown]
# ### Examples of Class 1

# %%
for i in range(0, 10):
    data = ds_dummy.__getitem__(i)[0]
    target = ds_dummy.__getitem__(i)[1]
    plot_image(data, target)

# %%
dict_args = dict()
dict_args["batch_size"] = 256
dict_args["no_cuda"] = False
dict_args["optimizer"] = "Adam"
dict_args["lr"] = 1e-2
dict_args["epochs"] = 50
dict_args["margin"] = 0.5
dict_args["log_interval"] = None
dict_args["seed"] = 1

use_cuda = not dict_args["no_cuda"] and torch.cuda.is_available()

torch.manual_seed(dict_args["seed"])

device = torch.device("cuda" if use_cuda else "cpu")

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

print("use_cuda :", use_cuda)
print("device :", device)
# Out:
# use_cuda : False
# device : cpu

# %%
train_loader = DataLoader(ds_dummy, 
                         batch_size=dict_args["batch_size"], 
                         shuffle=False, **kwargs)

for batch_idx, (data, target) in enumerate(train_loader):
    print(data.shape, target.shape)
    break

train_batch_sampler = BalancedBatchSampler(ds_dummy, n_classes=2, n_samples=256)
online_train_loader = DataLoader(ds_dummy, batch_sampler=train_batch_sampler, **kwargs)

for batch_idx, (data, target) in enumerate(online_train_loader):
    print(data.shape, target.shape)
    break
# Out:
# torch.Size([256, 1, 9, 29]) torch.Size([256])
# torch.Size([392, 1, 9, 29]) torch.Size([392])

# %%
# Select negative point when ap_distance + margin > an_distance 
# loss_fn = OnlineNonLinearTripletLoss(MarginallyHardNegativeTripletSelector(dict_args["margin"]),
#                                      max_dist=2,
#                                      beta1=2,
#                                      beta2=2.01,
#                                      epsilon=1e-8)

# %%
# loss_fn = OnlineNonLinearTripletLoss(SemiHardNegativeTripletSelector(dict_args["margin"]),
#                                      max_dist=2,
#                                      beta1=2,
#                                      beta2=2.01,
#                                      epsilon=1e-8)

# %%
loss_fn = OnlineTripletLoss(dict_args["margin"], MarginallyHardNegativeTripletSelector(dict_args["margin"]))

# %%
def load_model(path=None):
    model = NormEmbeddingNet([1, 50, 20], 
                             ds_dummy.n_grps, 
                             ds_dummy.n_steps,
                             kernel_size=3, 
                             dropout=0.1,
                             fc_nodes=[50, 50, 2],
                             p=2)
    if path is not None:
        model.load_state_dict(torch.load(path))
    return model

model = load_model(None)
model = model.to(device)

# %%
#loss_fn = TripletLoss(dict_args["margin"])
optimizer = getattr(torch.optim, dict_args["optimizer"])(model.parameters(), lr=dict_args["lr"])
# scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)

# %% [markdown]
# ## Initial Embeddings

# %%
train_embeddings, train_labels = extract_embedding(train_loader, model, use_cuda)
fig, ax = plt.subplots(figsize=(6,6))
plot_2d_circle()
plot_2d_embedding(train_embeddings, 
                  train_labels, 
                  ax=ax, xlim=[-1.5, 1.5], 
                  ylim=[-1.5, 1.5])

# %% [markdown]
# ## Train Model

# %%
dict_train_loss = {}
list_end_epochs = [50, 500, 1000]
start_epoch = 0
for i, end_epoch in enumerate(list_end_epochs):
    tmp_dict_train_loss, _ = fit(online_train_loader, 
                                         None, 
                                         model, 
                                         loss_fn, 
                                         optimizer, None, 
                                         end_epoch, 
                                         use_cuda, 
                                         dict_args["log_interval"], 
                                         metrics=[AverageNonZeroTripletsMetric()],
                                         start_epoch=start_epoch)
    
    torch.save(model.state_dict(), "linear_triplet_norm_net_{}.pt".format(end_epoch))
    
    start_epoch = end_epoch
    
    dict_train_loss.update(tmp_dict_train_loss)
# Out:
# Epoch [1/50]: Avg. Train Loss: 1.22967 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [2/50]: Avg. Train Loss: 0.93112 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [3/50]: Avg. Train Loss: 0.68720 | Avg. Non-Zero Triplets: 41797.50000
# Epoch [4/50]: Avg. Train Loss: 0.67064 | Avg. Non-Zero Triplets: 41735.00000
# Epoch [5/50]: Avg. Train Loss: 0.59693 | Avg. Non-Zero Triplets: 41681.50000
# Epoch [6/50]: Avg. Train Loss: 0.67906 | Avg. Non-Zero Triplets: 41777.00000
# Epoch [7/50]: Avg. Train Loss: 0.53786 | Avg. Non-Zero Triplets: 41728.50000
# Epoch [8/50]: Avg. Train Loss: 0.54376 | Avg. Non-Zero Triplets: 41748.00000
# Epoch [9/50]: Avg. Train Loss: 0.52711 | Avg. Non-Zero Triplets: 41708.00000
# Epoch [10/50]: Avg. Train Loss: 0.58125 | Avg. Non-Zero Triplets: 41760.50000
# Epoch [11/50]: Avg. Train Loss: 0.63654 | Avg. Non-Zero Triplets: 41792.00000
# Epoch [12/50]: Avg. Train Loss: 0.55776 | Avg. Non-Zero Triplets: 41771.00000
# Epoch [13/50]: Avg. Train Loss: 0.57026 | Avg. Non-Zero Triplets: 41751.00000
# Epoch [14/50]: Avg. Train Loss: 0.49894 | Avg. Non-Zero Triplets: 41763.50000
# Epoch [15/50]: Avg. Train Loss: 0.53238 | Avg. Non-Zero Triplets: 41760.00000
# Epoch [16/50]: Avg. Train Loss: 0.56635 | Avg. Non-Zero Triplets: 41815.50000
# Epoch [17/50]: Avg. Train Loss: 0.53647 | Avg. Non-Zero Triplets: 41740.00000
# Epoch [18/50]: Avg. Train Loss: 0.54978 | Avg. Non-Zero Triplets: 41764.00000
# Epoch [19/50]: Avg. Train Loss: 0.55772 | Avg. Non-Zero Triplets: 41120.00000
# Epoch [20/50]: Avg. Train Loss: 0.52807 | Avg. Non-Zero Triplets: 41655.50000
# Epoch [21/50]: Avg. Train Loss: 0.51350 | Avg. Non-Zero Triplets: 41790.50000
# Epoch [22/50]: Avg. Train Loss: 0.55431 | Avg. Non-Zero Triplets: 41660.50000
# Epoch [23/50]: Avg. Train Loss: 0.55417 | Avg. Non-Zero Triplets: 41670.50000
# Epoch [24/50]: Avg. Train Loss: 0.47886 | Avg. Non-Zero Triplets: 40337.00000
# Epoch [25/50]: Avg. Train Loss: 0.56784 | Avg. Non-Zero Triplets: 41603.50000
# Epoch [26/50]: Avg. Train Loss: 0.52056 | Avg. Non-Zero Triplets: 40220.50000
# Epoch [27/50]: Avg. Train Loss: 0.49708 | Avg. Non-Zero Triplets: 41153.50000
# Epoch [28/50]: Avg. Train Loss: 0.55873 | Avg. Non-Zero Triplets: 41565.00000
# Epoch [29/50]: Avg. Train Loss: 0.50178 | Avg. Non-Zero Triplets: 41222.00000
# Epoch [30/50]: Avg. Train Loss: 0.57919 | Avg. Non-Zero Triplets: 26491.50000
# Epoch [31/50]: Avg. Train Loss: 0.63120 | Avg. Non-Zero Triplets: 22790.50000
# Epoch [32/50]: Avg. Train Loss: 0.51399 | Avg. Non-Zero Triplets: 19706.50000
# Epoch [33/50]: Avg. Train Loss: 0.54622 | Avg. Non-Zero Triplets: 30376.50000
# Epoch [34/50]: Avg. Train Loss: 0.85914 | Avg. Non-Zero Triplets: 17306.50000
# Epoch [35/50]: Avg. Train Loss: 0.72799 | Avg. Non-Zero Triplets: 28873.50000
# Epoch [36/50]: Avg. Train Loss: 0.56345 | Avg. Non-Zero Triplets: 37370.50000
# Epoch [37/50]: Avg. Train Loss: 0.68602 | Avg. Non-Zero Triplets: 41812.00000
# Epoch [38/50]: Avg. Train Loss: 0.63320 | Avg. Non-Zero Triplets: 41816.50000
# Epoch [39/50]: Avg. Train Loss: 0.71991 | Avg. Non-Zero Triplets: 30091.00000
# Epoch [40/50]: Avg. Train Loss: 0.63478 | Avg. Non-Zero Triplets: 41817.00000
# Epoch [41/50]: Avg. Train Loss: 1.01441 | Avg. Non-Zero Triplets: 18812.00000
# Epoch [42/50]: Avg. Train Loss: 0.85087 | Avg. Non-Zero Triplets: 20915.00000
# Epoch [43/50]: Avg. Train Loss: 0.69196 | Avg. Non-Zero Triplets: 23764.00000
# Epoch [44/50]: Avg. Train Loss: 0.60079 | Avg. Non-Zero Triplets: 26367.00000
# Epoch [45/50]: Avg. Train Loss: 0.53317 | Avg. Non-Zero Triplets: 31069.50000
# Epoch [46/50]: Avg. Train Loss: 0.49014 | Avg. Non-Zero Triplets: 26768.50000
# Epoch [47/50]: Avg. Train Loss: 0.51792 | Avg. Non-Zero Triplets: 26588.50000
# Epoch [48/50]: Avg. Train Loss: 0.56343 | Avg. Non-Zero Triplets: 40555.50000
# Epoch [49/50]: Avg. Train Loss: 0.51395 | Avg. Non-Zero Triplets: 39956.00000
# Epoch [50/50]: Avg. Train Loss: 0.59373 | Avg. Non-Zero Triplets: 13725.00000
# Epoch [51/500]: Avg. Train Loss: 0.59031 | Avg. Non-Zero Triplets: 28089.50000
# Epoch [52/500]: Avg. Train Loss: 0.56518 | Avg. Non-Zero Triplets: 14568.50000
# Epoch [53/500]: Avg. Train Loss: 0.60354 | Avg. Non-Zero Triplets: 14279.50000
# Epoch [54/500]: Avg. Train Loss: 0.53185 | Avg. Non-Zero Triplets: 11131.50000
# Epoch [55/500]: Avg. Train Loss: 0.58831 | Avg. Non-Zero Triplets: 13038.50000
# Epoch [56/500]: Avg. Train Loss: 0.49799 | Avg. Non-Zero Triplets: 9918.50000
# Epoch [57/500]: Avg. Train Loss: 0.49712 | Avg. Non-Zero Triplets: 29027.50000
# Epoch [58/500]: Avg. Train Loss: 0.55951 | Avg. Non-Zero Triplets: 26249.50000
# Epoch [59/500]: Avg. Train Loss: 0.52102 | Avg. Non-Zero Triplets: 40605.00000
# Epoch [60/500]: Avg. Train Loss: 0.49470 | Avg. Non-Zero Triplets: 38898.50000
# Epoch [61/500]: Avg. Train Loss: 0.47306 | Avg. Non-Zero Triplets: 25321.50000
# Epoch [62/500]: Avg. Train Loss: 0.70056 | Avg. Non-Zero Triplets: 12822.50000
# Epoch [63/500]: Avg. Train Loss: 0.62545 | Avg. Non-Zero Triplets: 26229.50000
# Epoch [64/500]: Avg. Train Loss: 0.48421 | Avg. Non-Zero Triplets: 41395.50000
# Epoch [65/500]: Avg. Train Loss: 0.54058 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [66/500]: Avg. Train Loss: 0.46247 | Avg. Non-Zero Triplets: 41654.50000
# Epoch [67/500]: Avg. Train Loss: 0.50272 | Avg. Non-Zero Triplets: 41689.00000
# Epoch [68/500]: Avg. Train Loss: 0.47795 | Avg. Non-Zero Triplets: 41820.00000
# Epoch [69/500]: Avg. Train Loss: 0.58406 | Avg. Non-Zero Triplets: 25882.50000

# %% [markdown]
# ## Training Loss Plot

# %%
fig, ax = plt.subplots(figsize=(15,4))
ax.plot(dict_train_loss.keys(), dict_train_loss.values(), marker="o", label="Training Loss")
ax.set_xlabel("Epoch")
ax.set_ylabel("Training Loss")
ax.grid()
ax.legend();

# %% [markdown]
# ## Trained Embeddings after 50 Epochs

# %%
model = load_model("linear_triplet_norm_net_50.pt")

train_embeddings, train_labels = extract_embedding(train_loader, model, use_cuda)
fig, ax = plt.subplots(figsize=(6,6))
plot_2d_circle()
plot_2d_embedding(train_embeddings, 
                  train_labels, 
                  ax=ax, xlim=[-1.5, 1.5], 
                  ylim=[-1.5, 1.5])

# %% [markdown]
# ## Trained Embeddings after 500 Epochs

# %%
model = load_model("linear_triplet_norm_net_500.pt")

train_embeddings, train_labels = extract_embedding(train_loader, model, use_cuda)
fig, ax = plt.subplots(figsize=(6,6))
plot_2d_circle()
plot_2d_embedding(train_embeddings, 
                  train_labels, 
                  ax=ax, xlim=[-1.5, 1.5], 
                  ylim=[-1.5, 1.5])

# %% [markdown]
# ## Trained Embeddings after 1000 Epochs

# %%
model = load_model("linear_triplet_norm_net_1000.pt")

train_embeddings, train_labels = extract_embedding(train_loader, model, use_cuda)
fig, ax = plt.subplots(figsize=(6,6))
plot_2d_circle()
plot_2d_embedding(train_embeddings, 
                  train_labels, 
                  ax=ax, xlim=[-1.5, 1.5], 
                  ylim=[-1.5, 1.5])
